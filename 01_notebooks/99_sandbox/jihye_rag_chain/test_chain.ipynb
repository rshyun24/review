# %% [markdown]
# # 환경설정

# %%
import sys
sys.path.append(".")  # jihye_rag_chain 폴더 기준

import os
os.environ["OPENAI_API_KEY"] = "sk-..."  # 또는 .env 사용

# %% [markdown]
# # dense 검색 테스트

# %%
from chain import get_answer

result = get_answer(
    query="나이아신아마이드 EWG 등급이 어떻게 돼?",
    search_type="dense"
)
print(result["answer"])
print("---출처---")
for s in result["sources"]:
    print(s)
# Out:
# C:\Users\Playdata\anaconda3\envs\aistudy_env\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (6.0.0.post1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from chain import get_answer
#       3 result = get_answer(
#       4     query="나이아신아마이드 EWG 등급이 어떻게 돼?",
#       5     search_type="dense"
#       6 )
#       7 print(result["answer"])
#
# File C:\lecture\project\FLOW\01_notebooks\99_sandbox\jihye_rag_chain\chain.py:15
#      13 from langchain_core.output_parsers import StrOutputParser
#      14 from langchain_core.runnables import RunnablePassthrough, RunnableLambda
# ---> 15 from langchain.retrievers import ContextualCompressionRetriever
# ...

# %% [markdown]
# # 검색 방식 비교

# %%
for method in ["bm25", "dense", "rrf", "hyde"]:
    result = get_answer("레티놀 민감성 피부에 써도 돼?", search_type=method)
    print(f"\n[{method}]")
    print(result["answer"][:200])
