# %%
import os
print(os.getcwd())
os.chdir("C:/team projects/flow/01_notebooks/01_preprocessing/visualization")
print(os.getcwd())
from dotenv import load_dotenv
load_dotenv()
# Out:
# C:\python
# C:\team projects\flow\01_notebooks\01_preprocessing\visualization
# True

# %% [markdown]
# # 5단계 검색 방식 성능 비교 시각화
# BM25 / Dense / RRF / HyDE 4가지 방식 비교

# %%
import sys, os

BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), '..'))  # 01_preprocessing
sys.path.append(BASE_DIR)

print("BASE_DIR:", BASE_DIR)  # 확인용

from minha_retriever import CosmeticRetriever, load_faiss_auto
from minha_evaluator import Evaluator

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # Windows 한글
# matplotlib.rcParams['font.family'] = 'AppleGothic'  # Mac 한글
matplotlib.rcParams['axes.unicode_minus'] = False

FAISS_PATH = '../../../00_data/02_processed/faiss_index_preset1'
# Out:
# BASE_DIR: C:\team projects\flow\01_notebooks\01_preprocessing

# %% [markdown]
# ## 1. 데이터 및 Retriever 초기화

# %%
faiss_index, documents = load_faiss_auto(FAISS_PATH)
retriever = CosmeticRetriever(faiss_index=faiss_index, documents=documents, top_k=5)
print('초기화 완료')
# Out:
# [INFO] FAISS 차원: 1536d
# [INFO] Document 41797개 로드 완료
# 초기화 완료

# %% [markdown]
# ## 2. 테스트 쿼리 + 정답 설정

# %%
# 쿼리와 정답 성분명(ingredient_ko) 목록
TEST_CASES = [
    {
        'query': '나이아신아마이드 안전한가요?',
        'relevant': ['나이아신아마이드', '니코틴아마이드', '비타민 B3']
    },
    {
        'query': '건성 피부에 좋은 성분',
        'relevant': [
            '세라마이드',
            '히알루론산', '소듐하이알루로네이트', '하이알루론산나트륨',
            '판테놀', '프로비타민B5'
        ]
    },
    {
        'query': '레티놀 부작용',
        'relevant': ['레티놀', '레티닐팔미테이트', '레틴산']
    },
]

print(f'테스트 쿼리 {len(TEST_CASES)}개 준비 완료')
# Out:
# 테스트 쿼리 3개 준비 완료

# %% [markdown]
# ## 3. 4가지 방법 검색 + 평가 지표 계산

# %%
METHODS = ['bm25', 'dense', 'rrf', 'hyde']
fn_map  = {
    'bm25':  retriever.search_bm25,
    'dense': retriever.search_dense,
    'rrf':   retriever.search_rrf,
    'hyde':  retriever.search_hyde,
}

all_records = []

for tc in TEST_CASES:
    query    = tc['query']
    relevant = tc['relevant']
    evaluator = Evaluator(relevant_ids=relevant)
    print(f"\n쿼리: '{query}'")

    for m in METHODS:
        resp   = fn_map[m](query)
        result = evaluator.evaluate(resp)
        all_records.append({
            'query':      query,
            'method':     m.upper(),
            'Precision@3': result.precision_at_3,
            'Recall@3':   result.recall_at_3,
            'MRR':        result.mrr,
            'NDCG@3':     result.ndcg_at_3,
            'latency_ms': resp.latency_ms,
        })
        print(f'  [{m.upper():<5}] P@3={result.precision_at_3:.2f} R@3={result.recall_at_3:.2f} MRR={result.mrr:.2f} NDCG@3={result.ndcg_at_3:.2f} ({resp.latency_ms:.0f}ms)')

df = pd.DataFrame(all_records)
print('\n완료!')

print('\n\n====디버깅====')
debug_query = '건성 피부에 좋은 성분'
for m in ['bm25', 'dense', 'rrf']:
    resp = fn_map[m](debug_query)  # ← query → debug_query 로 수정
    print(f"\n[{m.upper()}] 실제 반환 결과:")
    for r in resp.results:
        name = r.document.metadata.get('ingredient_ko', '?')
        chunk = r.document.metadata.get('chunk_type', '?')
        print(f"  {r.rank}. {name} ({chunk}) score={r.score:.4f}")
# Out:
# 쿼리: '나이아신아마이드 안전한가요?'
#   [BM25 ] P@3=0.67 R@3=0.67 MRR=1.00 NDCG@3=0.77 (44ms)
#   [DENSE] P@3=0.33 R@3=0.33 MRR=1.00 NDCG@3=0.47 (334ms)
#   [RRF  ] P@3=1.00 R@3=1.00 MRR=1.00 NDCG@3=1.00 (199ms)
#
#   [HyDE 생성 성분명] ['나이아신아마이드', '판테놀', '알란토인', '세라마이드', '알로에베라잎추출물']
#   [HyDE 검색결과]
#     1. 알란토인 (RRF=0.0320)
#     2. 알로에베라잎추출물 (RRF=0.0302)
#     3. 나이아신아마이드 (RRF=0.0164)
#     4. 판테놀 (RRF=0.0164)
#     5. 알란토인 (RRF=0.0164)
#   [HYDE ] P@3=0.33 R@3=0.33 MRR=0.33 NDCG@3=0.23 (2963ms)
#
# 쿼리: '건성 피부에 좋은 성분'
#   [BM25 ] P@3=0.00 R@3=0.00 MRR=0.00 NDCG@3=0.00 (55ms)
#   [DENSE] P@3=0.00 R@3=0.00 MRR=0.00 NDCG@3=0.00 (154ms)
#   [RRF  ] P@3=0.00 R@3=0.00 MRR=0.00 NDCG@3=0.00 (213ms)
#
#   [HyDE 생성 성분명] ['세라마이드', '히알루론산', '글리세린', '판테놀', '쉐어버터']
#   [HyDE 검색결과]
#     1. 세라마이드 (RRF=0.0164)
#     2. 소듐카복시메틸하이알루로네이트 (RRF=0.0164)
#     3. 하이알루로니다아제 (RRF=0.0164)
#     4. 글리세린 (RRF=0.0164)
#     5. 판테놀 (RRF=0.0164)
#   [HYDE ] P@3=0.33 R@3=0.17 MRR=1.00 NDCG@3=0.47 (2539ms)
#
# 쿼리: '레티놀 부작용'
#   [BM25 ] P@3=0.33 R@3=0.33 MRR=1.00 NDCG@3=0.47 (39ms)
#   [DENSE] P@3=0.33 R@3=0.33 MRR=0.33 NDCG@3=0.23 (261ms)
#   [RRF  ] P@3=0.67 R@3=0.67 MRR=1.00 NDCG@3=0.77 (180ms)
#
#   [HyDE 생성 성분명] ['레티놀', '토코페롤', '알란토인', '판테놀', '센텔라아시아티카추출물']
#   [HyDE 검색결과]
#     1. 알란토인 (RRF=0.0320)
#     2. 레티놀 (RRF=0.0164)
#     3. 토코페롤 (RRF=0.0164)
#     4. 토코페솔란 (RRF=0.0164)
#     5. 알란토인 (RRF=0.0164)
#   [HYDE ] P@3=0.33 R@3=0.33 MRR=0.50 NDCG@3=0.30 (2128ms)
#
# 완료!
#
#
# ====디버깅====
#
# [BM25] 실제 반환 결과:
#   1. 세톨레스-30 (expert) score=1.0000
#   2. 쌀왁스 (expert) score=0.7564
#   3. 패션프룻씨오일 (expert) score=0.7352
#   4. 2-카프릴로일카프릴로일메틸알라니네이트 (expert) score=0.7270
#   5. 다이-글리세릴스테아레이트다이머다이리놀리에이트 (expert) score=0.7270
#
# [DENSE] 실제 반환 결과:
#   1. 지질 (expert) score=0.3981
#   2. 피부 컨디셔닝 성분 (expert) score=0.3919
#   3. 피부 회복 성분 (expert) score=0.3354
#   4. 팥추출물 (expert) score=0.3341
#   5. 피부 보충 성분 (expert) score=0.3295
#
# [RRF] 실제 반환 결과:
#   1. 세톨레스-30 (expert) score=0.0164
#   2. 지질 (expert) score=0.0164
#   3. 쌀왁스 (expert) score=0.0161
#   4. 피부 컨디셔닝 성분 (expert) score=0.0161
#   5. 패션프룻씨오일 (expert) score=0.0159

# %% [markdown]
# ## 4. 평균 지표 테이블

# %%
metrics = ['Precision@3', 'Recall@3', 'MRR', 'NDCG@3', 'latency_ms']
avg_df  = df.groupby('method')[metrics].mean().round(4)
avg_df.columns.name = None
avg_df.index.name   = '방법'
avg_df
# Out:
#        Precision@3  Recall@3     MRR  NDCG@3  latency_ms
# 방법
# BM25        0.3333    0.3333  0.6667  0.4116     46.0974
# DENSE       0.2222    0.2222  0.4444  0.2346    249.9032
# HYDE        0.3333    0.2778  0.6111  0.3333   2543.1081
# RRF         0.5556    0.5556  0.6667  0.5885    197.2222

# %% [markdown]
# ## 5. 차트 시각화

# %%
COLORS  = {'BM25': '#4A90D9', 'DENSE': '#50C878', 'RRF': '#9B59B6', 'HYDE': '#E67E22'}
METRICS = ['Precision@3', 'Recall@3', 'MRR', 'NDCG@3']

fig, axes = plt.subplots(1, 4, figsize=(18, 5))
fig.suptitle('검색 방식별 성능 지표 비교 (평균)', fontsize=15, fontweight='bold', y=1.02)

for ax, metric in zip(axes, METRICS):
    methods = avg_df.index.tolist()
    values  = avg_df[metric].tolist()
    colors  = [COLORS.get(m, '#95A5A6') for m in methods]

    bars = ax.bar(methods, values, color=colors, width=0.5, edgecolor='white', linewidth=1.2)
    ax.set_title(metric, fontsize=12, fontweight='bold')
    ax.set_ylim(0, 1.05)
    ax.set_ylabel('Score')
    ax.spines[['top', 'right']].set_visible(False)
    ax.grid(axis='y', alpha=0.3)

    for bar, val in zip(bars, values):
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 0.02,
            f'{val:.3f}',
            ha='center', fontsize=10, fontweight='bold'
        )

plt.tight_layout()
plt.savefig('stage5_metrics.png', dpi=150, bbox_inches='tight')
plt.show()
print('저장: stage5_metrics.png')
# Out:
# 저장: stage5_metrics.png

# %% [markdown]
# ## 6. 응답시간 비교

# %%
fig, ax = plt.subplots(figsize=(8, 4))

methods  = avg_df.index.tolist()
latency  = avg_df['latency_ms'].tolist()
colors   = [COLORS.get(m, '#95A5A6') for m in methods]

bars = ax.barh(methods, latency, color=colors, edgecolor='white', linewidth=1.2)
ax.set_xlabel('평균 응답시간 (ms)')
ax.set_title('검색 방식별 평균 응답시간', fontsize=13, fontweight='bold')
ax.spines[['top', 'right']].set_visible(False)
ax.grid(axis='x', alpha=0.3)

for bar, val in zip(bars, latency):
    ax.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2,
            f'{val:.0f}ms', va='center', fontsize=10)

plt.tight_layout()
plt.savefig('stage5_latency.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7. 쿼리별 점수 히트맵

# %%
import numpy as np

pivot = df.pivot_table(index='query', columns='method', values='NDCG@3')

fig, ax = plt.subplots(figsize=(9, 4))
im = ax.imshow(pivot.values, cmap='YlGn', aspect='auto', vmin=0, vmax=1)

ax.set_xticks(range(len(pivot.columns)))
ax.set_xticklabels(pivot.columns, fontsize=11)
ax.set_yticks(range(len(pivot.index)))
ax.set_yticklabels([q[:15] + '...' for q in pivot.index], fontsize=9)
ax.set_title('쿼리별 NDCG@3 히트맵', fontsize=13, fontweight='bold')

for i in range(len(pivot.index)):
    for j in range(len(pivot.columns)):
        val = pivot.values[i, j]
        ax.text(j, i, f'{val:.2f}', ha='center', va='center',
                fontsize=11, color='black' if val < 0.6 else 'white')

plt.colorbar(im, ax=ax, label='NDCG@3')
plt.tight_layout()
plt.savefig('stage5_heatmap.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 🔍 쿼리 유형별 검색 방식 성능 분석
#
# ### 핵심 결론
# > **BM25 / DENSE / RRF** 는 쿼리에 **성분명이 포함된 경우**에만 정상 동작한다.
# > **HyDE** 는 성분명 없는 개념형 쿼리에서도 성분명을 자체 생성하여 검색하므로 유일하게 유효한 결과를 반환한다.
#
# ---
#
# ### 쿼리 유형별 방법론 적합성
#
# | 쿼리 | 유형 | BM25 | DENSE | RRF | HyDE |
# |------|------|:----:|:-----:|:---:|:----:|
# | `나이아신아마이드 안전한가요?` | 성분명 포함 | ✅ | ✅ | ✅ | ✅ |
# | `레티놀 부작용` | 성분명 포함 | ✅ | ✅ | ✅ | ✅ |
# | `건성 피부에 좋은 성분` | **개념형** | ❌ | ❌ | ❌ | ✅ |
#
# ---
#
# ### 방법론별 동작 원리 요약
#
# | 방법 | 동작 방식 | 개념형 쿼리 취약 이유 |
# |------|----------|----------------------|
# | **BM25** | 키워드 텍스트 매칭 | 쿼리 키워드가 문서에 없으면 매칭 불가 |
# | **DENSE** | 임베딩 벡터 유사도 | 카테고리/설명 문서가 상위 노출됨 |
# | **RRF** | BM25 + DENSE 합산 | 두 방식 모두 실패하면 합산도 무의미 |
# | **HyDE** | 가상 답변 생성 → 성분명 추출 → 검색 | 성분명을 직접 생성하므로 개념형 쿼리에 강함 |
#
# ---
#
# ### 인사이트
#
# - `건성 피부에 좋은 성분` 쿼리에서 BM25/DENSE/RRF 전부 **0점**이 나온 것은 검색 시스템의 실패가 아니라,
#   **성분명 기반 DB에서 개념형 쿼리를 처리할 때의 구조적 한계**를 보여주는 것
# - HyDE가 이 케이스에서 유일하게 유효한 결과(`세라마이드`, `판테놀` 등)를 반환한 것은
#   **HyDE의 존재 이유를 실험적으로 증명**한 사례
# - 실제 서비스에서는 **쿼리 유형을 분류**하여 개념형 쿼리에는 HyDE를 우선 적용하는 전략이 유효할 수 있음
